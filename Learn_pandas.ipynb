# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cbbbc408-98e2-4573-950b-a38e4e427567" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbbbc408-98e2-4573-950b-a38e4e427567">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("EDA_Automobile_Case_Studyt.csv")

# %%
df1 = pd.read_excel("PayrollCloud Assignment - 1.xlsx")

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df1.head()
# Out:
#      Rules & Scenarios      Unnamed: 1  \
# 0        Employee Type  Hospital Nurse
# 1      Employee Salary        100/Hour
# 2    Working Hours/Day               9
# 3  Working days / week               5
# 4           Pay Period        Biweekly
#
#                                           Unnamed: 2 Unnamed: 3
# 0                                                NaN        NaN
# 1  Any time spend on supervision of patient will ...        NaN
# 2             Shift can start at any time of the day        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN

# %%
df.to_csv('data.csv')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df[['fuel-type','drive-wheels']]
# Out:
#     fuel-type drive-wheels
# 0         gas          rwd
# 1         gas          rwd
# 2         gas          rwd
# 3         gas          fwd
# 4         gas          4wd
# ..        ...          ...
# 200       gas          rwd
# 201       gas          rwd
# 202       gas          rwd
# 203    diesel          rwd
# 204       gas          rwd
#
# [205 rows x 2 columns]

# %%
# prompt: how to check all unique on table with name

df.nunique()
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
#df.index
df.describe
# Out:
# <bound method NDFrame.describe of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['fuel-system']
# Out:
# 0      mpfi
# 1      mpfi
# 2      mpfi
# 3      mpfi
# 4      mpfi
#        ...
# 200    mpfi
# 201    mpfi
# 202    mpfi
# 203     idi
# 204    mpfi
# Name: fuel-system, Length: 205, dtype: object

# %%
df[['fuel-system','city-mpg']]
# Out:
#     fuel-system  city-mpg
# 0          mpfi        21
# 1          mpfi        21
# 2          mpfi        19
# 3          mpfi        24
# 4          mpfi        18
# ..          ...       ...
# 200        mpfi        23
# 201        mpfi        19
# 202        mpfi        18
# 203         idi        26
# 204        mpfi        19
#
# [205 rows x 2 columns]

# %%
df.iloc[1::2]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 1            3                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 7            1                 ?         audi       gas        std
# 9            0                 ?         audi       gas      turbo
# ..         ...               ...          ...       ...        ...
# 195         -1                74        volvo       gas        std
# 197         -1                74        volvo       gas        std
# 199         -1                74        volvo       gas      turbo
# 201         -1                95        volvo       gas      turbo
# 203         -1                95        volvo    diesel      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.iloc[:,:3]
# Out:
#      symboling normalized-losses         make
# 0            3                 ?  alfa-romero
# 1            3                 ?  alfa-romero
# 2            1                 ?  alfa-romero
# 3            2               164         audi
# 4            2               164         audi
# ..         ...               ...          ...
# 200         -1                95        volvo
# 201         -1                95        volvo
# 202         -1                95        volvo
# 203         -1                95        volvo
# 204         -1                95        volvo
#
# [205 rows x 3 columns]

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df[df['body-style']=='sedan'][df['fuel-type']== 'diesel']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-1edcace54100> in <cell line: 1>()
# ----> 1 df[df['body-style']=='sedan']|[df['fuel-type']== 'diesel']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __or__(self, other)
#      78     @unpack_zerodim_and_defer("__or__")
#      79     def __or__(self, other):
# ---> 80         return self._logical_method(other, operator.or_)
#      81
#      82     @unpack_zerodim_and_defer("__ror__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
# ...

# %%
# prompt: how to write this "df[df['body-style']=='sedan'][df['fuel-type']== 'diesel']" with and operator

df[(df['body-style'] == 'sedan') & (df['fuel-type'] == 'diesel')]

# %%
df[(df['body-style']=='wagon') | (df['aspiration']=='std')]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 196         -2               103        volvo       gas        std
# 197         -1                74        volvo       gas        std
# 199         -1                74        volvo       gas      turbo
# 200         -1                95        volvo       gas        std
# 202         -1                95        volvo       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data = {'name':['chirag','jay','vanshraj','pravin','vipul'],
        'age':[21,22,25,30,40],
        'TestScore_1':[4,24,31,2,3],
        'TestScore_2':[25,94,57,62,60]
        }

# %%
df= pd.DataFrame(data,columns=['name','age','TestScore_1','TestScore_2'])

# %%
df
# Out:
#        name  age  TestScore_1  TestScore_2
# 0    chirag   21            4           25
# 1       jay   22           24           94
# 2  vanshraj   25           31           57
# 3    pravin   30            2           62
# 4     vipul   40            3           60

# %%
df['age'].sum()
# Out:
# 138

# %%
#df['TestScore_1'].mean()
#df['TestScore_1'].count()
#df['TestScore_1'].min()
#df['TestScore_1'].max()
#df['TestScore_1'].median()
#df['TestScore_1'].var()
df['TestScore_1'].std()
df['TestScore_1'].skew()
df['TestScore_1'].kurt()
#df.corr()
df.cov()
# Out:
# <ipython-input-97-c012707e84a2>:11: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                age  TestScore_1  TestScore_2
# age          60.30       -49.85        13.30
# TestScore_1 -49.85       186.70       153.15
# TestScore_2  13.30       153.15       598.30

# %%
df['TestScore_2'].cumsum()
# Out:
# 0     25
# 1    119
# 2    176
# 3    238
# 4    298
# Name: TestScore_2, dtype: int64

# %%
df['TestScore_1'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: TestScore_1, dtype: float64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.hist(column='num-of-doors',by='fuel-type',bins=10)
# Out:
# array([<Axes: title={'center': 'diesel'}>,
#        <Axes: title={'center': 'gas'}>], dtype=object)

# %%
import numpy as np

# %%
df = pd.read_csv('bigmart_data.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df = pd.read_csv('bigmart_data.csv')
df = df.dropna(how='any')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
# sorted_data = df.sort_values(by = 'Outlet_Establishment_Year')
# sorted_data[:5]
sorted_data = df.sort_values(by='Outlet_Establishment_Year')
sorted_data[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2812           FDR60        14.30          Low Fat         0.130307
# 5938           NCJ06        20.10          Low Fat         0.034624
# 3867           FDY38        13.60          Regular         0.119077
# 1307           FDB37        20.25          Regular         0.022922
# 5930           NCA18        10.10          Low Fat         0.056031
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2812  Baking Goods   75.7328            OUT013                       1987
# 5938     Household  118.9782            OUT013                       1987
# 3867         Dairy  231.2300            OUT013                       1987
# 1307  Baking Goods  240.7538            OUT013                       1987
# 5930     Household  115.1492            OUT013                       1987
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
sorted_data = df.sort_values(by = 'Outlet_Establishment_Year',ascending=False)
sorted_data[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2825           FDL16        12.85          Low Fat         0.169139
# 7389           NCD42        16.50          Low Fat         0.012689
# 2165           DRJ39        20.25          Low Fat         0.036474
# 2162           FDR60        14.30          Low Fat         0.130946
# 2158           FDM58        16.85          Regular         0.080015
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2825        Frozen Foods   46.4060            OUT018
# 7389  Health and Hygiene   39.7506            OUT018
# 2165               Dairy  218.3482            OUT018
# 2162        Baking Goods   76.7328            OUT018
# 2158         Snack Foods  111.8544            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2825                       2009      Medium               Tier 3
# 7389                       2009      Medium               Tier 3
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
sort_values = df.sort_values(by=['Outlet_Establishment_Year','Outlet_Size'],ascending = False)[:5]
sort_values
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1            DRC01        5.920          Regular         0.019278
# 5            FDP36       10.395          Regular         0.000000
# 16           NCB42       11.800          Low Fat         0.008596
# 31           NCS17       18.600          Low Fat         0.080829
# 32           FDP33       18.700          Low Fat         0.000000
#
#              Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 1          Soft Drinks   48.2692            OUT018                       2009
# 5         Baking Goods   51.4008            OUT018                       2009
# 16  Health and Hygiene  115.3492            OUT018                       2009
# 31  Health and Hygiene   96.4436            OUT018                       2009
# 32         Snack Foods  256.6672            OUT018                       2009
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.sort_index(inplace=True)
df[:5]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df_ages = pd.DataFrame({'age': np.random.randint(21,55,8)})
#df_ages = pd.DataFrame({'age': np.random.randint(21, 51, 8)})
df_ages
# Out:
#    age
# 0   31
# 1   34
# 2   54
# 3   46
# 4   24
# 5   29
# 6   51
# 7   28

# %%
df_ages['bins_ages']= pd.cut(x = df_ages['age'],bins=[20,30,40,50,60])
df_ages
# Out:
#    age bins_ages
# 0   31  (30, 40]
# 1   34  (30, 40]
# 2   54  (50, 60]
# 3   46  (40, 50]
# 4   24  (20, 30]
# 5   29  (20, 30]
# 6   51  (50, 60]
# 7   28  (20, 30]

# %%
df_ages['bins_ages'].unique()
# Out:
# [(30, 40], (50, 60], (40, 50], (20, 30]]
# Categories (4, interval[int64, right]): [(20, 30] < (30, 40] < (40, 50] < (50, 60]]

# %%
df_ages['bins_ages_lable'] = pd.cut(x=df_ages['age'],bins=[20,30,40,50,60],labels=['20s','30s','40s','50s'])
df_ages
# Out:
#    age bins_ages bins_ages_lable
# 0   31  (30, 40]             30s
# 1   34  (30, 40]             30s
# 2   54  (50, 60]             50s
# 3   46  (40, 50]             40s
# 4   24  (20, 30]             20s
# 5   29  (20, 30]             20s
# 6   51  (50, 60]             50s
# 7   28  (20, 30]             20s

# %% [markdown]
# **Handling Missing **

# %%
df1 = pd.DataFrame({'A':[1,2,None,4],'B':[5,None,7,8]})
print(df1.isnull())
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True  False
# 3  False  False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       3 non-null      float64
# dtypes: float64(2)
# memory usage: 192.0 bytes

# %%
df1['A'].fillna(value=df1['A'].mean(),inplace=True)
#df['B'].fillna(value=df['A'].median(),inplace=True)

# %%
#df1.interpolate()
df1['B'].fillna(value=df1['B'].mean(),inplace=True)
df1
# Out:
#           A         B
# 0  1.000000  5.000000
# 1  2.000000  6.666667
# 2  2.333333  7.000000
# 3  4.000000  8.000000

# %%
df.apply(lambda x:x)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.apply(lambda x:x[0:10:2])
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 2           FDN15        17.50          Low Fat         0.016760
# 4           NCD19         8.93          Low Fat         0.000000
# 6           FDO10        13.65          Regular         0.012741
# 8           FDH17        16.20          Regular         0.016687
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 6   Snack Foods   57.6588            OUT013                       1987
# 8  Frozen Foods   96.9726            OUT045                       2002
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df.apply(lambda x:x[0],axis=1)
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Length: 8523, dtype: object

# %%
df.apply(lambda x:x['Outlet_Identifier'],axis=1)
# Out:
# 0       OUT049
# 1       OUT018
# 2       OUT049
# 3       OUT010
# 4       OUT013
#          ...
# 8518    OUT013
# 8519    OUT045
# 8520    OUT035
# 8521    OUT018
# 8522    OUT046
# Length: 8523, dtype: object

# %%
df.apply(lambda x:x['Outlet_Establishment_Year'],axis=1)
# Out:
# 0       1999
# 1       2009
# 2       1999
# 3       1998
# 4       1987
#         ...
# 8518    1987
# 8519    2002
# 8520    2004
# 8521    2009
# 8522    1997
# Length: 8523, dtype: int64

# %%
df['Item_MRP'][:5]
# Out:
# 0    249.8092
# 1     48.2692
# 2    141.6180
# 3    182.0950
# 4     53.8614
# Name: Item_MRP, dtype: float64

# %%
def clip_price(price):
  if price > 200:
    price=200
  return price

# %%
df['Item_MRP'].apply(lambda x:clip_price(x))[:5]
# Out:
# 0    200.0000
# 1     48.2692
# 2    141.6180
# 3    182.0950
# 4     53.8614
# Name: Item_MRP, dtype: float64

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
def label_encoder(city):
    if city == 'Tier 1':
        label = 0
    elif city == 'Tier 2':
        label = 1
    else:
        label = 2

    return label


# df['Outlet_Location_Type']=df['Outlet_Location_Type'].apply(lambda x:change_loction(x))[:5]
df['Outlet_Location_Type'] = df['Outlet_Location_Type'].apply(change_location)
df['Outlet_Location_Type'][:5]
# Out:
# 0    1
# 1    3
# 2    1
# 4    3
# 5    3
# Name: Outlet_Location_Type, dtype: int64

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
df = df.reset_index(drop = True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              NCD19        8.930          Low Fat         0.000000
# 4              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 4645           FDF53       20.750              reg         0.083607
# 4646           FDF22        6.865          Low Fat         0.056783
# 4647           NCJ29       10.600          Low Fat         0.035186
# 4648           FDN46        7.210          Regular         0.145221
# 4649           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
price_by_iteam = df.groupby('Item_Type')
price_by_iteam.first()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36       10.395          Regular
# Breads                          FDW11       12.600          Low Fat
# Breakfast                       FDP49        9.000          Regular
# Canned                          FDC02       21.350          Low Fat
# Dairy                           FDA15        9.300          Low Fat
# Frozen Foods                    FDR28       13.850          Regular
# Fruits and Vegetables           FDY07       11.800          Low Fat
# Hard Drinks                     DRJ59       11.650          low fat
# Health and Hygiene              NCB42       11.800          Low Fat
# Household                       NCD19        8.930          Low Fat
# Meat                            FDN15       17.500          Low Fat
# Others                          NCM43       14.500          Low Fat
# Seafood                         FDH21       10.395          Low Fat
# ...

# %%
price_by_iteam.Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Meat                     140.279344
# Others                   137.640870
# Seafood                  146.595782
# Snack Foods              147.569955
# Soft Drinks              130.910182
# Starchy Foods            151.256747
# Name: Item_MRP, dtype: float64

# %%
multiple_groups = df[:10].groupby(['Item_Type','Item_Fat_Content'])
multiple_groups.first()
# Out:
#                                        Item_Identifier  Item_Weight  \
# Item_Type             Item_Fat_Content
# Baking Goods          Regular                    FDP36       10.395
# Dairy                 Low Fat                    FDA15        9.300
#                       Regular                    FDA03       18.500
# Fruits and Vegetables Low Fat                    FDY07       11.800
#                       Regular                    FDX32       15.100
# Household             Low Fat                    NCD19        8.930
# Meat                  Low Fat                    FDN15       17.500
# Snack Foods           Regular                    FDO10       13.650
# Soft Drinks           Regular                    DRC01        5.920
#
#                                         Item_Visibility  Item_MRP  \
# Item_Type             Item_Fat_Content
# Baking Goods          Regular                  0.000000   51.4008
# Dairy                 Low Fat                  0.016047  249.8092
# ...

# %%
pd.crosstab(df['Outlet_Size'],df['Outlet_Location_Type'] ,margins=True)
# Out:
# Outlet_Location_Type     1    2     3   All
# Outlet_Size
# High                     0    0   932   932
# Medium                 930    0   928  1858
# Small                  930  930     0  1860
# All                   1860  930  1860  4650

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year'],values = 'Item_Outlet_Sales')
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1987                             2298.995256
# 1997                             2277.844267
# 1999                             2348.354635
# 2004                             2438.841866
# 2009                             1995.498739

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'],values = 'Item_Outlet_Sales')
# Out:
#                                                             Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      3                    High               2298.995256
# 1997                      1                    Small              2277.844267
# 1999                      1                    Medium             2348.354635
# 2004                      2                    Small              2438.841866
# 2009                      3                    Medium             1995.498739

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'],values = 'Item_Outlet_Sales',aggfunc=[np.mean,np.median,min,max,np.std])
# Out:
#                                                                         mean  \
#                                                            Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      3                    High              2298.995256
# 1997                      1                    Small             2277.844267
# 1999                      1                    Medium            2348.354635
# 2004                      2                    Small             2438.841866
# 2009                      3                    Medium            1995.498739
#
#                                                                       median  \
#                                                            Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      3                    High                2050.6640
# 1997                      1                    Small               1945.8005
# ...

# %%
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']}
                   ,index=[0,1,2,3])
df2 = pd.DataFrame({'A':['A4','A5','A6','A7'],
                    'B':['B4','B5','B6','B7'],
                    'C':['C4','C5','C6','C7'],
                    'D':['D4','D5','D6','D7']}
                   ,index=[4,5,6,7])
df3 = pd.DataFrame({'A':['A8','A9','A10','A11'],
                    'B':['B8','B9','B10','B11'],
                    'C':['C8','C9','C10','C11'],
                    'D':['D8','D9','D10','D11']}
                   ,index=[8,9,10,11])

# %%
print(df1)

print(df2)

print(df3)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1,df2,df3])
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1,df2,df3],keys=['x','y','z'])
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df4 = pd.DataFrame({'B':['B2','B3','B6','B7'],
                   'D':['D2','D3','D6','D7'],
                   'F':['F2','F3','F6','F7']},
                   index=[2,3,6,7])
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
result1 =pd.concat([df1,df4],axis=1,sort=False)
result1
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result1 =pd.concat([df1,df4],axis=1,sort=False,join='inner')
result1
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
df_a = pd.DataFrame({'Subject_Id':['1','2','3','4'],
                     'First_Name':['chirag','jay','vinay','pravin'],
                     'Last_Name':['Gohil','Aacharya','patil','joshi']})
df_b = pd.DataFrame({'Subject_Id':['3','4','5','6'],
                     'First_Name':['ajay','jayrajsinh','vipul','prakash'],
                     'Last_Name':['gajera','Aacharya','patel','joshi']})
df_c = pd.DataFrame({'Subject_Id':['1','2','3','5','6','7','8'],
                    'Test_id':[33,45,67,22,66,1,77]})

# %%
df_a
# Out:
#   Subject_Id First_Name Last_Name
# 0          1     chirag     Gohil
# 1          2        jay  Aacharya
# 2          3      vinay     patil
# 3          4     pravin     joshi

# %%
df_b
# Out:
#   Subject_Id  First_Name Last_Name
# 0          3        ajay    gajera
# 1          4  jayrajsinh  Aacharya
# 2          5       vipul     patel
# 3          6     prakash     joshi

# %%
df_c
# Out:
#   Subject_Id  Test_id
# 0          1       33
# 1          2       45
# 2          3       67
# 3          5       22
# 4          6       66
# 5          7        1
# 6          8       77

# %%
# pd.merge(df_a,df_b,on='Subject_Id',how='outer')
# pd.merge(df_a,df_b,on='Subject_Id',how='inner')
# pd.merge(df_a,df_b,on='Subject_Id',how='right')
pd.merge(df_a,df_b,on='Subject_Id',how='left')
# Out:
#   Subject_Id First_Name_x Last_Name_x First_Name_y Last_Name_y
# 0          1       chirag       Gohil          NaN         NaN
# 1          2          jay    Aacharya          NaN         NaN
# 2          3        vinay       patil         ajay      gajera
# 3          4       pravin       joshi   jayrajsinh    Aacharya

# %%
df_0 = pd.DataFrame({'id':[0,1,2,3,4,5,6,7,8],
                     'marks':[20,30,40,50,10,40,70,80,22]})
df_0
# Out:
#    id  marks
# 0   0     20
# 1   1     30
# 2   2     40
# 3   3     50
# 4   4     10
# 5   5     40
# 6   6     70
# 7   7     80
# 8   8     22

# %%
# df_0['id'].map(lambda x:3+x)
#df_0['id'].map(lambda x:'hii'+x)#if column2 format has string
#df_0[['id','marks']].apply(sum)
# func =lambda x:x+2
# df_0.applymap(func)
df_0.nunique()
df_0.isnull()
# Out:
#       id  marks
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False

# %%
# df_0.describe()
df_0.cov()
df_0.corr()
# Out:
#              id     marks
# id     1.000000  0.408383
# marks  0.408383  1.000000
